# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("C:/AI/Raisin_Dataset.xlsx", index_col=0)
df
# Out:
#        MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  \
# Area
# 87524       442.246011       253.291155      0.819738       90546  0.758651
# 75166       406.690687       243.032436      0.801805       78789  0.684130
# 90856       442.267048       266.328318      0.798354       93717  0.637613
# 45928       286.540559       208.760042      0.684989       47336  0.699599
# 79408       352.190770       290.827533      0.564011       81463  0.792772
# ...                ...              ...           ...         ...       ...
# 83248       430.077308       247.838695      0.817263       85839  0.668793
# 87350       440.735698       259.293149      0.808629       90899  0.636476
# 99657       431.706981       298.837323      0.721684      106264  0.741099
# 93523       476.344094       254.176054      0.845739       97653  0.658798
# 85609       512.081774       215.271976      0.907345       89197  0.632020
#
#        Perimeter    Class
# Area
# 87524   1184.040  Kecimen
# 75166   1121.786  Kecimen
# 90856   1208.575  Kecimen
# 45928    844.162  Kecimen
# 79408   1073.251  Kecimen
# ...          ...      ...
# 83248   1129.072    Besni
# 87350   1214.252    Besni
# 99657   1292.828    Besni
# 93523   1258.548    Besni
# 85609   1272.862    Besni
#
# [900 rows x 7 columns]

# %%
.csv는 read_csv / .xlsx는 read_excel

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'ConvexArea',
#        'Extent', 'Perimeter', 'Class'],
#       dtype='object')

# %%
X=df.drop('Class',axis=1)
X.head(5)
# Out:
#        MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  \
# Area
# 87524       442.246011       253.291155      0.819738       90546  0.758651
# 75166       406.690687       243.032436      0.801805       78789  0.684130
# 90856       442.267048       266.328318      0.798354       93717  0.637613
# 45928       286.540559       208.760042      0.684989       47336  0.699599
# 79408       352.190770       290.827533      0.564011       81463  0.792772
#
#        Perimeter
# Area
# 87524   1184.040
# 75166   1121.786
# 90856   1208.575
# 45928    844.162
# 79408   1073.251

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'ConvexArea',
#        'Extent', 'Perimeter', 'Class'],
#       dtype='object')

# %%
# 레이블 갯수 확인 (그래프)

sns.countplot(data=df, x="Class")
plt.ylabel("Count")
plt.title("Class Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # 레이블 갯수 확인 (그래프)
#       3 sns.countplot(data=df, x="Class")
# ----> 4 plt.ylabel("Count")
#       5 plt.title("Class Distribution")
#       6 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# 레이블 갯수 확인 (숫자)
df['Class'].value_counts()
# Out:
# Class
# Kecimen    450
# Besni      450
# Name: count, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# MajorAxisLength    0
# MinorAxisLength    0
# Eccentricity       0
# ConvexArea         0
# Extent             0
# Perimeter          0
# Class              0
# dtype: int64

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'ConvexArea',
#        'Extent', 'Perimeter', 'Class'],
#       dtype='object')

# %%
# 산점도 확인

import matplotlib.pyplot as plt
import numpy as np

plt.scatter(df['MajorAxisLength'], df['MinorAxisLength'])
plt.xlabel('MajorAxisLengt')
plt.ylabel('MinorAxisLength')

plt.show()

# %%
# pairplot를 사용해 각 상관관계 살펴보기

sns.pairplot(df,
             vars=['MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'ConvexArea',
       'Extent', 'Perimeter'],
            hue ='Class')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 특정 칼럼의 범위 확인 및 outlier 확인

sns.set_theme(style="whitegrid")
sns.boxplot(x="MajorAxisLength", data=df, palette="Set3")
plt.title("MajorAxisLength")
plt.show()

# %%
# 각 컬럼별 히스토 그램 확인

fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22636\2498552643.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax = ax)

# %%
X=df.drop('Class',axis=1)
X.head()
# Out:
#        MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  \
# Area
# 87524       442.246011       253.291155      0.819738       90546  0.758651
# 75166       406.690687       243.032436      0.801805       78789  0.684130
# 90856       442.267048       266.328318      0.798354       93717  0.637613
# 45928       286.540559       208.760042      0.684989       47336  0.699599
# 79408       352.190770       290.827533      0.564011       81463  0.792772
#
#        Perimeter
# Area
# 87524   1184.040
# 75166   1121.786
# 90856   1208.575
# 45928    844.162
# 79408   1073.251

# %%
y=df['Class']
y.value_counts()
# Out:
# Class
# Kecimen    450
# Besni      450
# Name: count, dtype: int64

# %%
y=df['Class']
y.head(5)
# Out:
# Area
# 87524    Kecimen
# 75166    Kecimen
# 90856    Kecimen
# 45928    Kecimen
# 79408    Kecimen
# Name: Class, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
iris_ML = LogisticRegression(random_state=0)
iris_ML.fit(X_train, y_train)

pred_iris_ML = iris_ML.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_iris_ML))
print (confusion_matrix(y_test, pred_iris_ML))
# Out:
# --- Logistic Regression Classifier ---
# 0.8844444444444445
# [[ 98  17]
#  [  9 101]]
