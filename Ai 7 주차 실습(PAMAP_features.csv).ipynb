# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/AI/PAMAP_features.csv", index_col=0)
df
# Out:
#        sub_id  activity_id act_level     hr_mean  hr_mean_normal    hr_std  \
# 3006        2           17     light   87.000000        1.175676  0.000000
# 3497        2            4  moderate  124.605469        1.683858  0.927920
# 14495       7            5  vigorous  113.493430        1.891557  2.315888
# 13278       7           17     light   82.513672        1.375228  0.492657
# 14969       8            3     light   73.000000        1.106061  0.000000
# ...       ...          ...       ...         ...             ...       ...
# 10708       6            2     light   82.582031        1.376367  0.930285
# 4870        3            2     light   76.998047        1.132324  0.806906
# 11822       6            4  moderate   93.445312        1.557422  0.493415
# 3866        2            7  moderate  129.160156        1.745408  0.361877
# 3450        2           13  moderate  142.234375        1.922086  1.714464
#
#        hr_std_normal  hand_tmp_mean  hand_tmp_std  hand_acc_x_mean  ...  \
# 3006    7.105427e-15      34.375000      0.000000        -1.165524  ...
# 3497    1.253946e-02      31.875000      0.000000       -12.040995  ...
# 14495   3.859813e-02      32.500000      0.000000        -3.723040  ...
# 13278   8.210948e-03      33.812500      0.000000        -3.618932  ...
# 14969   7.327472e-15      34.437500      0.000000        -9.275877  ...
# ...              ...            ...           ...              ...  ...
# 10708   1.550475e-02      33.525635      0.030741        -4.306831  ...
# 4870    1.186626e-02      32.083130      0.029390        -1.545991  ...
# 11822   8.223580e-03      31.750000      0.000000       -10.034760  ...
# 3866    4.890232e-03      30.465576      0.031088        -8.275569  ...
# 3450    2.316843e-02      32.173340      0.026163        -3.077000  ...
#
#        ankle_acc_xz_cor  hand_gyr_xy_cor  hand_gyr_yz_cor  hand_gyr_xz_cor  \
# 3006           0.233251        -0.472662         0.335516        -0.377507
# 3497          -0.119772        -0.287380        -0.230390        -0.491314
# 14495          0.025673        -0.265566         0.824691        -0.121345
# 13278          0.724061        -0.196728         0.315984        -0.380337
# 14969         -0.001651        -0.060776         0.165672         0.311760
# ...                 ...              ...              ...              ...
# 10708          0.193950        -0.354026         0.175876        -0.172933
# 4870           0.135629         0.056979         0.008235         0.001093
# 11822         -0.404942         0.520845        -0.951838        -0.561901
# 3866          -0.136336        -0.147614        -0.344375        -0.329746
# 3450           0.200755        -0.081262         0.130816        -0.278256
#
#        chest_gyr_xy_cor  chest_gyr_yz_cor  chest_gyr_xz_cor  ankle_gyr_xy_cor  \
# 3006          -0.290138         -0.779952          0.071855         -0.305959
# 3497           0.011124         -0.799319         -0.135736         -0.653133
# 14495         -0.004923         -0.317761         -0.202148         -0.660278
# 13278          0.284190         -0.109078         -0.071734         -0.177813
# 14969         -0.272620         -0.014943         -0.191610         -0.261158
# ...                 ...               ...               ...               ...
# 10708          0.184131         -0.274344         -0.485489         -0.100010
# 4870          -0.203294         -0.097797         -0.273316         -0.009717
# 11822         -0.169119          0.299434         -0.100683         -0.555866
# 3866          -0.024487         -0.536806         -0.161019         -0.752563
# 3450          -0.254757         -0.723943         -0.039044         -0.016410
#
#        ankle_gyr_yz_cor  ankle_gyr_xz_cor
# 3006          -0.003001         -0.638866
# 3497          -0.654575          0.391363
# 14495         -0.528138          0.402147
# 13278          0.237828         -0.729771
# 14969          0.066954          0.057685
# ...                 ...               ...
# 10708         -0.000800          0.031654
# 4870          -0.076216          0.009411
# 11822         -0.442849          0.063207
# 3866          -0.627185          0.436639
# 3450          -0.662742         -0.085954
#
# [11773 rows x 67 columns]

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
label=LabelEncoder()

df['sub_id']=label.fit_transform(df['sub_id'])
df['act_level']=label.fit_transform(df['act_level'])
df.head()
# Out:
#        sub_id  activity_id  act_level     hr_mean  hr_mean_normal    hr_std  \
# 3006        1           17          0   87.000000        1.175676  0.000000
# 3497        1            4          1  124.605469        1.683858  0.927920
# 14495       6            5          2  113.493430        1.891557  2.315888
# 13278       6           17          0   82.513672        1.375228  0.492657
# 14969       7            3          0   73.000000        1.106061  0.000000
#
#        hr_std_normal  hand_tmp_mean  hand_tmp_std  hand_acc_x_mean  ...  \
# 3006    7.105427e-15        34.3750           0.0        -1.165524  ...
# 3497    1.253946e-02        31.8750           0.0       -12.040995  ...
# 14495   3.859813e-02        32.5000           0.0        -3.723040  ...
# 13278   8.210948e-03        33.8125           0.0        -3.618932  ...
# 14969   7.327472e-15        34.4375           0.0        -9.275877  ...
#
#        ankle_acc_xz_cor  hand_gyr_xy_cor  hand_gyr_yz_cor  hand_gyr_xz_cor  \
# 3006           0.233251        -0.472662         0.335516        -0.377507
# 3497          -0.119772        -0.287380        -0.230390        -0.491314
# 14495          0.025673        -0.265566         0.824691        -0.121345
# 13278          0.724061        -0.196728         0.315984        -0.380337
# 14969         -0.001651        -0.060776         0.165672         0.311760
#
#        chest_gyr_xy_cor  chest_gyr_yz_cor  chest_gyr_xz_cor  ankle_gyr_xy_cor  \
# 3006          -0.290138         -0.779952          0.071855         -0.305959
# 3497           0.011124         -0.799319         -0.135736         -0.653133
# 14495         -0.004923         -0.317761         -0.202148         -0.660278
# 13278          0.284190         -0.109078         -0.071734         -0.177813
# 14969         -0.272620         -0.014943         -0.191610         -0.261158
#
#        ankle_gyr_yz_cor  ankle_gyr_xz_cor
# 3006          -0.003001         -0.638866
# 3497          -0.654575          0.391363
# 14495         -0.528138          0.402147
# 13278          0.237828         -0.729771
# 14969          0.066954          0.057685
#
# [5 rows x 67 columns]

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# sub_id              0
# activity_id         0
# act_level           0
# hr_mean             0
# hr_mean_normal      0
#                    ..
# chest_gyr_yz_cor    0
# chest_gyr_xz_cor    0
# ankle_gyr_xy_cor    0
# ankle_gyr_yz_cor    0
# ankle_gyr_xz_cor    0
# Length: 67, dtype: int64

# %%
import seaborn as sns

import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
# 각 열의 레이블 확인 및 개수 세기
for column in df.columns:
    print(f"Column: {column}")
    print(df[column].value_counts())
    print()
# Out:
# Column: sub_id
# sub_id
# 4    1651
# 1    1618
# 7    1576
# 5    1556
# 0    1518
# 6    1430
# 3    1353
# 2    1042
# 8      29
# Name: count, dtype: int64
#
# Column: activity_id
# activity_id
# 17    1539
# 4     1525
# 3     1220
# 1     1203
# 7     1196
# 2     1162
# 16    1099
# 6     1035
# 5      593
# 12     522
# 13     428
# 24     251
# Name: count, dtype: int64
#
# Column: act_level
# act_level
# 1    5283
# 0    5124
# 2    1366
# Name: count, dtype: int64
#
# Column: hr_mean
# hr_mean
# 119.000000    81
# 124.000000    77
# 120.000000    66
# 79.000000     59
# 71.000000     56
#               ..
# 71.101562      1
# 125.919922     1
# 80.703125      1
# 129.625000     1
# 142.234375     1
# Name: count, Length: 8979, dtype: int64
#
# Column: hr_mean_normal
# hr_mean_normal
# 1.750000    51
# 1.000000    35
# 1.878788    35
# 1.090909    29
# 1.600000    27
#             ..
# 1.230022     1
# 2.123165     1
# 1.859931     1
# 2.183392     1
# 1.922086     1
# Name: count, Length: 9923, dtype: int64
#
# Column: hr_std
# hr_std
# 0.000000    2031
# 0.457374      89
# 0.466765      67
# 0.492707      35
# 0.452097      23
#             ...
# 0.978555       1
# 0.631141       1
# 1.822576       1
# 1.089519       1
# 1.714464       1
# Name: count, Length: 5137, dtype: int64
#
# Column: hr_std_normal
# hr_std_normal
# 0.000000e+00    123
# 1.043610e-14     83
# 5.773160e-15     72
# 1.132427e-14     61
# 4.440892e-15     54
#                ...
# 1.425850e-02      1
# 1.476680e-02      1
# 1.503101e-02      1
# 5.874194e-03      1
# 2.316843e-02      1
# Name: count, Length: 7687, dtype: int64
#
# Column: hand_tmp_mean
# hand_tmp_mean
# 33.812500    295
# 33.687500    225
# 33.000000    189
# 34.750000    169
# 32.937500    150
#             ...
# 34.030151      1
# 34.593140      1
# 31.088623      1
# 29.066406      1
# 32.173340      1
# Name: count, Length: 3916, dtype: int64
#
# Column: hand_tmp_std
# hand_tmp_std
# 0.000000    6327
# 0.019809     899
# 0.019659     373
# 0.026163     288
# 0.026083     281
#             ...
# 0.028713       1
# 0.030324       1
# 0.019093       1
# 0.029774       1
# 0.029543       1
# Name: count, Length: 356, dtype: int64
#
# Column: hand_acc_x_mean
# hand_acc_x_mean
# -1.165524     1
# -10.207726    1
# -6.578706     1
# -2.290604     1
#  1.594714     1
#              ..
# -8.960885     1
# -0.606800     1
# -9.449946     1
# -5.705182     1
# -3.077000     1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_acc_x_std
# hand_acc_x_std
# 2.383779    1
# 2.236595    1
# 4.196691    1
# 3.077903    1
# 3.459303    1
#            ..
# 2.802907    1
# 5.413178    1
# 4.916072    1
# 4.041910    1
# 3.850697    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_acc_y_mean
# hand_acc_y_mean
#  3.381285    1
#  3.485607    1
# -0.401186    1
#  9.489406    1
#  5.827125    1
#             ..
# -2.829144    1
#  6.182392    1
#  1.938646    1
#  8.132167    1
#  3.495658    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_acc_y_std
# hand_acc_y_std
# 2.582771    1
# 2.152710    1
# 2.683992    1
# 8.114414    1
# 3.327425    1
#            ..
# 3.114407    1
# 5.478853    1
# 2.564558    1
# 6.649312    1
# 3.910041    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_acc_z_mean
# hand_acc_z_mean
# 8.492507    1
# 0.796798    1
# 7.658871    1
# 1.831462    1
# 5.713693    1
#            ..
# 0.583452    1
# 5.743564    1
# 1.584243    1
# 1.878668    1
# 8.028176    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_acc_z_std
# hand_acc_z_std
# 1.224852    1
# 1.616689    1
# 3.646583    1
# 2.673957    1
# 1.776052    1
#            ..
# 3.933988    1
# 3.586927    1
# 1.962114    1
# 2.267372    1
# 4.359921    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_gyr_x_mean
# hand_gyr_x_mean
#  0.093030    1
# -0.093269    1
# -0.259179    1
#  0.024663    1
#  0.025976    1
#             ..
# -0.082211    1
# -0.204685    1
#  0.816054    1
#  0.050561    1
#  0.129189    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_gyr_x_std
# hand_gyr_x_std
# 0.719383    1
# 2.233908    1
# 0.717753    1
# 0.717617    1
# 0.283714    1
#            ..
# 0.749771    1
# 1.044268    1
# 1.323151    1
# 1.182251    1
# 1.390107    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_gyr_y_mean
# hand_gyr_y_mean
# -0.080050    1
#  0.046071    1
# -0.164140    1
#  0.032011    1
# -0.110111    1
#             ..
# -0.181025    1
#  0.106678    1
# -0.204329    1
#  0.093291    1
# -0.301541    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_gyr_y_std
# hand_gyr_y_std
# 0.494687    1
# 0.924522    1
# 0.265143    1
# 0.493582    1
# 0.330953    1
#            ..
# 1.189438    1
# 0.632881    1
# 0.600048    1
# 0.635699    1
# 1.139699    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_gyr_z_mean
# hand_gyr_z_mean
# -0.170838    1
#  0.168133    1
#  0.140894    1
# -0.030579    1
#  0.280933    1
#             ..
#  0.021403    1
# -0.034643    1
# -0.079159    1
# -0.109257    1
# -0.282935    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_gyr_z_std
# hand_gyr_z_std
# 0.980066    1
# 2.055258    1
# 0.483891    1
# 1.560853    1
# 0.735604    1
#            ..
# 1.568588    1
# 0.408610    1
# 0.943375    1
# 2.130209    1
# 0.981932    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_tmp_mean
# chest_tmp_mean
# 37.625000    255
# 35.625000    220
# 37.687500    204
# 36.750000    183
# 36.687500    165
#             ...
# 36.718262      1
# 35.894165      1
# 37.484497      1
# 35.688965      1
# 36.700684      1
# Name: count, Length: 3517, dtype: int64
#
# Column: chest_tmp_std
# chest_tmp_std
# 0.000000    6390
# 0.019659    1136
# 0.026002     501
# 0.029477     280
# 0.031063     218
#             ...
# 0.030690       1
# 0.026006       1
# 0.029197       1
# 0.029331       1
# 0.022870       1
# Name: count, Length: 291, dtype: int64
#
# Column: chest_acc_x_mean
# chest_acc_x_mean
# -0.574081    1
#  0.759853    1
# -0.454184    1
#  0.602366    1
#  0.831137    1
#             ..
#  1.772714    1
# -0.153353    1
# -0.002126    1
#  0.440604    1
# -0.582784    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_acc_x_std
# chest_acc_x_std
# 0.956643    1
# 1.596891    1
# 0.738232    1
# 1.444871    1
# 0.211408    1
#            ..
# 1.413391    1
# 1.014372    1
# 1.739924    1
# 2.090378    1
# 1.760109    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_acc_y_mean
# chest_acc_y_mean
# 8.924554    1
# 9.849204    1
# 5.869994    1
# 9.859447    1
# 9.547032    1
#            ..
# 4.616139    1
# 4.396538    1
# 9.873146    1
# 9.949165    1
# 8.796645    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_acc_y_std
# chest_acc_y_std
# 0.575753    1
# 2.723984    1
# 1.793245    1
# 3.680085    1
# 0.101696    1
#            ..
# 4.287916    1
# 2.445637    1
# 5.418138    1
# 4.710887    1
# 4.616256    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_acc_z_mean
# chest_acc_z_mean
# -4.355411    1
# -0.662793    1
# -8.675215    1
# -0.236724    1
#  1.824125    1
#             ..
# -7.686142    1
# -8.910990    1
# -0.468777    1
# -0.726983    1
# -5.001611    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_acc_z_std
# chest_acc_z_std
# 0.852119    1
# 1.334698    1
# 1.982562    1
# 2.390627    1
# 0.182105    1
#            ..
# 2.129135    1
# 2.188795    1
# 1.961642    1
# 2.144239    1
# 3.502833    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_gyr_x_mean
# chest_gyr_x_mean
#  0.052130    1
#  0.010478    1
# -0.106905    1
#  0.008560    1
#  0.016776    1
#             ..
# -0.290883    1
# -0.104745    1
# -0.037243    1
#  0.020398    1
#  0.054004    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_gyr_x_std
# chest_gyr_x_std
# 0.172671    1
# 0.320763    1
# 0.471859    1
# 0.400614    1
# 0.053436    1
#            ..
# 0.481763    1
# 0.521791    1
# 0.445155    1
# 0.418006    1
# 0.803543    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_gyr_y_mean
# chest_gyr_y_mean
# -0.127863    1
#  0.031474    1
#  0.122873    1
#  0.018967    1
# -0.008112    1
#             ..
#  0.033515    1
#  0.008695    1
# -0.825150    1
#  0.007138    1
# -0.573017    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_gyr_y_std
# chest_gyr_y_std
# 0.550284    1
# 0.522245    1
# 0.315982    1
# 0.378464    1
# 0.038845    1
#            ..
# 0.373646    1
# 0.222748    1
# 0.802698    1
# 0.386304    1
# 0.924807    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_gyr_z_mean
# chest_gyr_z_mean
#  0.069405    1
# -0.040722    1
# -0.270344    1
# -0.007175    1
# -0.006616    1
#             ..
# -0.102398    1
# -0.010505    1
#  0.012918    1
# -0.019852    1
#  0.239986    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_gyr_z_std
# chest_gyr_z_std
# 0.261474    1
# 0.249589    1
# 0.360044    1
# 0.330533    1
# 0.037563    1
#            ..
# 0.248796    1
# 0.297581    1
# 0.286588    1
# 0.236474    1
# 0.567839    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_tmp_mean
# ankle_tmp_mean
# 34.437500    338
# 34.625000    294
# 34.125000    291
# 34.062500    273
# 33.875000    271
#             ...
# 34.232300      1
# 33.884766      1
# 33.031250      1
# 34.528687      1
# 34.553223      1
# Name: count, Length: 3149, dtype: int64
#
# Column: ankle_tmp_std
# ankle_tmp_std
# 0.000000    6761
# 0.019659     933
# 0.019507     328
# 0.026002     315
# 0.025920     284
#             ...
# 0.031058       1
# 0.025418       1
# 0.030605       1
# 0.030112       1
# 0.014954       1
# Name: count, Length: 354, dtype: int64
#
# Column: ankle_acc_x_mean
# ankle_acc_x_mean
# 9.613680     1
# 11.170449    1
# 9.933568     1
# 12.005063    1
# 8.950553     1
#             ..
# 9.666765     1
# 9.593572     1
# 11.950956    1
# 12.544212    1
# 10.531917    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_acc_x_std
# ankle_acc_x_std
# 0.141006     1
# 5.290103     1
# 2.304734     1
# 7.990228     1
# 0.068641     1
#             ..
# 1.424342     1
# 11.688972    1
# 11.868267    1
# 7.045900     1
# 7.902595     1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_acc_y_mean
# ankle_acc_y_mean
# -2.034883    1
#  0.862078    1
#  1.676354    1
#  1.401820    1
# -2.730550    1
#             ..
# -0.666030    1
#  3.437511    1
#  1.302981    1
#  1.395095    1
#  1.016846    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_acc_y_std
# ankle_acc_y_std
# 0.449276     1
# 8.870188     1
# 2.585505     1
# 12.439674    1
# 0.071483     1
#             ..
# 2.678932     1
# 7.429794     1
# 13.544226    1
# 12.651164    1
# 8.505999     1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_acc_z_mean
# ankle_acc_z_mean
# -0.675058    1
# -2.919412    1
# -1.360366    1
# -4.552525    1
# -3.721105    1
#             ..
# -3.097909    1
# -2.982807    1
# -4.043378    1
# -3.589564    1
# -1.063730    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_acc_z_std
# ankle_acc_z_std
# 0.722426    1
# 2.783372    1
# 1.215936    1
# 5.939236    1
# 0.100697    1
#            ..
# 2.084768    1
# 4.151719    1
# 6.875131    1
# 4.903756    1
# 4.352015    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_gyr_x_mean
# ankle_gyr_x_mean
#  0.003878    1
# -0.109023    1
#  0.304432    1
#  0.005757    1
#  0.010033    1
#             ..
#  0.018532    1
#  0.060664    1
# -0.749130    1
# -0.109758    1
# -0.672176    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_gyr_x_std
# ankle_gyr_x_std
# 0.260395    1
# 1.365127    1
# 0.453522    1
# 1.699654    1
# 0.026576    1
#            ..
# 1.011072    1
# 0.930126    1
# 2.679439    1
# 2.217403    1
# 1.807432    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_gyr_y_mean
# ankle_gyr_y_mean
# -0.039163    1
# -0.023154    1
#  0.094002    1
# -0.204807    1
# -0.000078    1
#             ..
#  0.057010    1
#  0.120112    1
# -0.582655    1
# -0.169277    1
# -0.201666    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_gyr_y_std
# ankle_gyr_y_std
# 0.099164    1
# 0.461182    1
# 0.271266    1
# 1.135975    1
# 0.024517    1
#            ..
# 0.516273    1
# 0.709811    1
# 1.059122    1
# 0.601141    1
# 0.958545    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_gyr_z_mean
# ankle_gyr_z_mean
#  0.003677    1
# -0.173634    1
#  0.235663    1
#  0.096291    1
#  0.006866    1
#             ..
# -0.021281    1
# -0.058484    1
#  0.166665    1
# -0.051663    1
#  0.059146    1
# Name: count, Length: 11773, dtype: int64
#
# Column: ankle_gyr_z_std
# ankle_gyr_z_std
# 0.141914    1
# 2.919166    1
# 0.492293    1
# 3.137853    1
# 0.016241    1
#            ..
# 0.760325    1
# 2.146066    1
# 3.346929    1
# 3.514879    1
# 2.740983    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_acc_xy_cor
# hand_acc_xy_cor
#  0.614900    1
# -0.228779    1
#  0.616517    1
# -0.424094    1
# -0.296003    1
#             ..
#  0.060128    1
#  0.022393    1
# -0.335014    1
# -0.612815    1
#  0.016263    1
# Name: count, Length: 11773, dtype: int64
#
# Column: hand_acc_yz_cor
# hand_acc_yz_cor
# -0.464277    2
# -0.749890    1
# -0.015246    1
#  0.310834    1
#  0.211386    1
#             ..
# -0.474337    1
#  0.043267    1
#  0.222011    1
#  0.559913    1
# -0.337069    1
# Name: count, Length: 11772, dtype: int64
#
# Column: hand_acc_xz_cor
# hand_acc_xz_cor
# -0.252158    1
#  0.030274    1
#  0.092328    1
#  0.224571    1
# -0.558774    1
#             ..
#  0.109671    1
# -0.576349    1
#  0.116611    1
# -0.389825    1
# -0.155138    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_acc_xy_cor
# chest_acc_xy_cor
# -0.096426    1
# -0.073186    1
#  0.106286    1
# -0.006147    1
# -0.000912    1
#             ..
#  0.156578    1
#  0.015917    1
#  0.245978    1
#  0.127325    1
#  0.026264    1
# Name: count, Length: 11773, dtype: int64
#
# Column: chest_acc_yz_cor
# chest_acc_yz_cor
# -0.025011    2
#  0.451917    1
#  0.047029    1
# -0.108360    1
# -0.515575    1
#             ..
# -0.417217    1
#  0.891322    1
#  0.202784    1
# -0.085904    1
# -0.761717    1
# Name: count, Length: 11772, dtype: int64
#
# Column: chest_acc_xz_cor
# chest_acc_xz_cor
# -0.123431    2
#  0.001699    2
#  0.017834    2
# -0.128077    1
# -0.084361    1
#             ..
#  0.190266    1
#  0.101170    1
# -0.098038    1
#  0.046158    1
# -0.095838    1
# Name: count, Length: 11770, dtype: int64
#
# Column: ankle_acc_xy_cor
# ankle_acc_xy_cor
#  0.167768    2
#  0.237329    2
#  0.324036    1
#  0.230732    1
#  0.198830    1
#             ..
# -0.533232    1
# -0.200600    1
#  0.254083    1
#  0.287767    1
#  0.141931    1
# Name: count, Length: 11771, dtype: int64
#
# Column: ankle_acc_yz_cor
# ankle_acc_yz_cor
#  0.020795    2
# -0.054578    2
# -0.259079    2
# -0.107256    2
# -0.111770    2
#             ..
#  0.075757    1
# -0.296723    1
#  0.222843    1
#  0.792450    1
#  0.067698    1
# Name: count, Length: 11767, dtype: int64
#
# Column: ankle_acc_xz_cor
# ankle_acc_xz_cor
# -0.131276    2
# -0.359864    2
#  0.233251    1
#  0.185395    1
# -0.135248    1
#             ..
#  0.160507    1
#  0.441332    1
# -0.450501    1
# -0.095026    1
#  0.200755    1
# Name: count, Length: 11771, dtype: int64
#
# Column: hand_gyr_xy_cor
# hand_gyr_xy_cor
# -0.055731    2
# -0.172420    2
# -0.080043    2
# -0.000904    2
# -0.120890    2
#             ..
# -0.164127    1
# -0.533698    1
# -0.546869    1
# -0.232685    1
# -0.081262    1
# Name: count, Length: 11766, dtype: int64
#
# Column: hand_gyr_yz_cor
# hand_gyr_yz_cor
#  0.011249    2
#  0.335516    1
# -0.373396    1
# -0.882405    1
#  0.002215    1
#             ..
# -0.055468    1
#  0.873875    1
# -0.177825    1
# -0.108331    1
#  0.130816    1
# Name: count, Length: 11772, dtype: int64
#
# Column: hand_gyr_xz_cor
# hand_gyr_xz_cor
# -0.606119    2
# -0.377507    1
# -0.326315    1
#  0.277534    1
#  0.217675    1
#             ..
#  0.263253    1
# -0.239897    1
# -0.104234    1
# -0.126581    1
# -0.278256    1
# Name: count, Length: 11772, dtype: int64
#
# Column: chest_gyr_xy_cor
# chest_gyr_xy_cor
# -0.018198    2
#  0.034307    2
# -0.220622    2
# -0.045913    1
#  0.052389    1
#             ..
# -0.340893    1
# -0.158388    1
# -0.062751    1
#  0.331393    1
# -0.254757    1
# Name: count, Length: 11770, dtype: int64
#
# Column: chest_gyr_yz_cor
# chest_gyr_yz_cor
# -0.068429    2
# -0.743035    2
# -0.741345    2
# -0.023289    2
# -0.002556    2
#             ..
# -0.075250    1
# -0.517148    1
#  0.016835    1
#  0.096309    1
# -0.723943    1
# Name: count, Length: 11767, dtype: int64
#
# Column: chest_gyr_xz_cor
# chest_gyr_xz_cor
# -0.217867    2
# -0.184348    2
# -0.137097    2
# -0.146261    2
# -0.093290    2
#             ..
# -0.048352    1
# -0.021906    1
# -0.169609    1
# -0.277980    1
# -0.039044    1
# Name: count, Length: 11765, dtype: int64
#
# Column: ankle_gyr_xy_cor
# ankle_gyr_xy_cor
#  0.135014    2
#  0.001733    2
# -0.228278    2
#  0.024231    2
# -0.398595    2
#             ..
#  0.139837    1
#  0.440459    1
# -0.162334    1
# -0.535365    1
# -0.016410    1
# Name: count, Length: 11768, dtype: int64
#
# Column: ankle_gyr_yz_cor
# ankle_gyr_yz_cor
# -0.023223    2
# -0.472860    2
# -0.514484    1
#  0.620589    1
# -0.359962    1
#             ..
#  0.552216    1
#  0.895913    1
# -0.548974    1
# -0.386777    1
# -0.662742    1
# Name: count, Length: 11771, dtype: int64
#
# Column: ankle_gyr_xz_cor
# ankle_gyr_xz_cor
#  0.002562    2
# -0.003080    2
#  0.088969    2
#  0.271844    2
#  0.447523    2
#             ..
#  0.070500    1
#  0.605802    1
#  0.139285    1
#  0.195686    1
# -0.085954    1
# Name: count, Length: 11768, dtype: int64

# %%
X=df.drop(['sub_id', 'activity_id'],axis=1)
X.head()
# Out:
#        act_level     hr_mean  hr_mean_normal    hr_std  hr_std_normal  \
# 3006           0   87.000000        1.175676  0.000000   7.105427e-15
# 3497           1  124.605469        1.683858  0.927920   1.253946e-02
# 14495          2  113.493430        1.891557  2.315888   3.859813e-02
# 13278          0   82.513672        1.375228  0.492657   8.210948e-03
# 14969          0   73.000000        1.106061  0.000000   7.327472e-15
#
#        hand_tmp_mean  hand_tmp_std  hand_acc_x_mean  hand_acc_x_std  \
# 3006         34.3750           0.0        -1.165524        2.383779
# 3497         31.8750           0.0       -12.040995        3.734766
# 14495        32.5000           0.0        -3.723040       10.188184
# 13278        33.8125           0.0        -3.618932        1.935690
# 14969        34.4375           0.0        -9.275877        0.082824
#
#        hand_acc_y_mean  ...  ankle_acc_xz_cor  hand_gyr_xy_cor  \
# 3006          3.381285  ...          0.233251        -0.472662
# 3497          3.069947  ...         -0.119772        -0.287380
# 14495        11.705779  ...          0.025673        -0.265566
# 13278         0.542981  ...          0.724061        -0.196728
# 14969         1.006239  ...         -0.001651        -0.060776
#
#        hand_gyr_yz_cor  hand_gyr_xz_cor  chest_gyr_xy_cor  chest_gyr_yz_cor  \
# 3006          0.335516        -0.377507         -0.290138         -0.779952
# 3497         -0.230390        -0.491314          0.011124         -0.799319
# 14495         0.824691        -0.121345         -0.004923         -0.317761
# 13278         0.315984        -0.380337          0.284190         -0.109078
# 14969         0.165672         0.311760         -0.272620         -0.014943
#
#        chest_gyr_xz_cor  ankle_gyr_xy_cor  ankle_gyr_yz_cor  ankle_gyr_xz_cor
# 3006           0.071855         -0.305959         -0.003001         -0.638866
# 3497          -0.135736         -0.653133         -0.654575          0.391363
# 14495         -0.202148         -0.660278         -0.528138          0.402147
# 13278         -0.071734         -0.177813          0.237828         -0.729771
# 14969         -0.191610         -0.261158          0.066954          0.057685
#
# [5 rows x 65 columns]

# %%
y=df['sub_id']
y.value_counts()
# Out:
# sub_id
# 4    1651
# 1    1618
# 7    1576
# 5    1556
# 0    1518
# 6    1430
# 3    1353
# 2    1042
# 8      29
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (9418, 65) (2355, 65) (9418,) (2355,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
print("\n--- Random Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
# Out:
# --- Random Forest ---

# %%
print(classification_report(y_test, pred))
print(confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       304
#            1       1.00      1.00      1.00       337
#            2       1.00      1.00      1.00       205
#            3       1.00      1.00      1.00       274
#            4       1.00      1.00      1.00       339
#            5       1.00      1.00      1.00       300
#            6       1.00      1.00      1.00       288
#            7       1.00      1.00      1.00       303
#            8       1.00      1.00      1.00         5
#
#     accuracy                           1.00      2355
#    macro avg       1.00      1.00      1.00      2355
# weighted avg       1.00      1.00      1.00      2355
#
# [[304   0   0   0   0   0   0   0   0]
#  [  0 337   0   0   0   0   0   0   0]
#  [  0   0 205   0   0   0   0   0   0]
#  [  0   0   0 274   0   0   0   0   0]
#  [  0   0   0   0 339   0   0   0   0]
#  [  0   0   0   0   0 300   0   0   0]
#  [  0   0   0   0   0   0 288   0   0]
#  [  0   0   0   0   0   0   0 303   0]
#  [  0   0   0   0   0   0   0   0   5]]

# %%
print(classification_report(y_test, pred))
print(confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       304
#            1       1.00      1.00      1.00       337
#            2       1.00      1.00      1.00       205
#            3       1.00      1.00      1.00       274
#            4       1.00      1.00      1.00       339
#            5       1.00      1.00      1.00       300
#            6       1.00      1.00      1.00       288
#            7       1.00      1.00      1.00       303
#            8       1.00      1.00      1.00         5
#
#     accuracy                           1.00      2355
#    macro avg       1.00      1.00      1.00      2355
# weighted avg       1.00      1.00      1.00      2355
#
# [[304   0   0   0   0   0   0   0   0]
#  [  0 337   0   0   0   0   0   0   0]
#  [  0   0 205   0   0   0   0   0   0]
#  [  0   0   0 274   0   0   0   0   0]
#  [  0   0   0   0 339   0   0   0   0]
#  [  0   0   0   0   0 300   0   0   0]
#  [  0   0   0   0   0   0 288   0   0]
#  [  0   0   0   0   0   0   0 303   0]
#  [  0   0   0   0   0   0   0   0   5]]

# %%
import warnings
warnings.filterwarnings('ignore')

print ("\n--- Radom Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
print(classification_report(y_test,pred_dt))
print(confusion_matrix(y_test,pred_dt))
# Out:
# --- Radom Forest ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       304
#            1       1.00      1.00      1.00       337
#            2       0.99      1.00      0.99       205
#            3       0.98      0.99      0.98       274
#            4       1.00      1.00      1.00       339
#            5       1.00      0.99      0.99       300
#            6       1.00      1.00      1.00       288
#            7       1.00      0.99      1.00       303
#            8       1.00      1.00      1.00         5
#
#     accuracy                           0.99      2355
#    macro avg       0.99      0.99      0.99      2355
# weighted avg       0.99      0.99      0.99      2355
#
# [[299   0   0   4   0   1   0   0   0]
#  [  0 337   0   0   0   0   0   0   0]
#  [  0   0 204   0   0   0   1   0   0]
#  [  2   0   1 271   0   0   0   0   0]
#  [  0   0   0   0 339   0   0   0   0]
#  [  0   0   2   0   0 298   0   0   0]
#  [  0   0   0   0   0   0 288   0   0]
#  [  0   0   0   2   0   0   0 301   0]
#  [  0   0   0   0   0   0   0   0   5]]
